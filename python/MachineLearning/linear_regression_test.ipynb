# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,root_mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.figure(figsize=(3,3))
sns.pairplot(data,x_vars=['YearsExperience'],y_vars='Salary',size=7,kind='scatter')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary Prediction')
plt.show()

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_train,linear_model.predict(x_train),color='red')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='blue')
plt.plot(x_test,linear_model.predict(x_test),color='red')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
mean_squared_error(y_test,linear_model.predict(x_test))
rms=root_mean_squared_error(y_test,linear_model.predict(x_test))
print("Root Mean Squared Error:",rms)
r2_score(y_test,linear_model.predict(x_test))
# Out:
# Root Mean Squared Error: 3580.979237321343
# 0.988169515729126

# %%
linear_model.intercept_
# Out:
# np.float64(26780.09915062818)

# %%
linear_model.coef_
# Out:
# array([9312.57512673])

# %%
x=float(input("Enter the years of experience: "))

# %%
y_pred=linear_model.coef_*x+linear_model.intercept_
print("Predicted Salary:",y_pred)
# Out:
# Predicted Salary: [73342.97478427]
