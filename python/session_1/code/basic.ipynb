# %%
x=30
print("My Age is " , x)
# Out:
# My Age is  30

# %%
name="Moooo"
age=21
print(f"My name is {name} and my age is {age}")
# Out:
# My name is Moooo and my age is 21

# %%
name=input("Enter your name: ")
age=input("Enter your age: ")
print(f"My name is {name} and my age is {age} ")
# Out:
# My name is Mooo and my age is 23
